# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import torch

# %%
image=plt.imread('../data/images/cfcu_002387.png')

# %%
plt.imshow
# Out:
# array([[[0.23137255, 0.24313726, 0.27450982],
#         [0.22745098, 0.24313726, 0.27450982],
#         [0.22745098, 0.24313726, 0.27058825],
#         ...,
#         [0.4862745 , 0.5568628 , 0.6039216 ],
#         [0.4862745 , 0.5568628 , 0.6039216 ],
#         [0.49019608, 0.5529412 , 0.60784316]],
#
#        [[0.22745098, 0.24313726, 0.27450982],
#         [0.22745098, 0.24313726, 0.27450982],
#         [0.22745098, 0.24705882, 0.27450982],
#         ...,
#         [0.49019608, 0.5568628 , 0.6       ],
#         [0.49019608, 0.5529412 , 0.6039216 ],
#         [0.49019608, 0.54901963, 0.6039216 ]],
#
#        [[0.23137255, 0.24705882, 0.27450982],
#         [0.22745098, 0.24313726, 0.27058825],
#         [0.22745098, 0.24705882, 0.27058825],
#         ...,
#         [0.49411765, 0.5529412 , 0.5921569 ],
#         [0.49411765, 0.5529412 , 0.6039216 ],
#         [0.49019608, 0.54509807, 0.6       ]],
#
#        ...,
#
#        [[0.19215687, 0.21568628, 0.25490198],
# ...
