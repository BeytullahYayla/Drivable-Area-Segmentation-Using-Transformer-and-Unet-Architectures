# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import torch
import os

# %%
import sys
sys.path.append('../src/')
from preprocess import  tensorize_image,torchlike_data,tensorize_mask,one_hot_encoder

# %%
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
image=plt.imread('../data/images/cfcu_002387.png')

# %%
plt.imshow(image)

# %%
image_paths=os.listdir('C:\\Users\\Beytullah\\Documents\\GitHub\\FordOtosan-L4Highway-Internship-Project\\data\\images')

# %%
image_paths
# Out:
# ['cfcu_002387.png',
#  'cfcu_002403.png',
#  'cfcu_002411.png',
#  'cfcu_002419.png',
#  'cfcu_002427.png',
#  'cfcu_002435.png',
#  'cfcu_002443.png',
#  'cfcu_002451.png',
#  'cfcu_002459.png',
#  'cfcu_002467.png',
#  'cfcu_002475.png',
#  'cfcu_002483.png',
#  'cfcu_002491.png',
#  'cfcu_002499.png']
